# %%
# %pip install --upgrade gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.18.5 in /home/juann/anaconda3/envs/DDB/lib/python3.11/site-packages (from gensim) (1.26.0)
# Requirement already satisfied: scipy>=1.7.0 in /home/juann/anaconda3/envs/DDB/lib/python3.11/site-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /home/juann/anaconda3/envs/DDB/lib/python3.11/site-packages (from gensim) (5.2.1)
# Downloading gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 17.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: gensim
# Successfully installed gensim-4.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import multiprocessing

# %%
df_fin_phrase = pd.read_csv('../../Data/Raw/fin_phrase_bank.csv')

# %%
df_fin_phrase.columns
# Out:
# Index(['sentence', 'label'], dtype='object')

# %%
def clean_data(text):
    
    text = re.sub(r'[\\/×\^\]\[÷]', '', text)
     # remove punctuation at the end of words
    text = re.sub(r'[.,!?]', ' ', text)
    # remove special characters except fo decimal points
    text = re.sub(r'[^a-zA-Z\s.]', ' ', text)
    # remove extra spaces
    text = re.sub(r'\s+', ' ', text)
    # remove leading and trailing spaces
    text = re.sub(r'^\s+|\s+?$', ' ', text.lower())
    return text
def change_lower(text):
    text = text.lower()
    return text

stopwords_list = stopwords.words("english")
def remover(text):
    text_tokens = text.split(" ")
    final_list = [word for word in text_tokens if not word in stopwords_list]
    text = ' '.join(final_list)
    return text

def get_w2vdf(df):
    w2v_df = pd.DataFrame(df["sentence"]).values.tolist()
    for i in range(len(w2v_df)):
        w2v_df[i] = w2v_df[i][0].split(" ")
    return w2v_df

# %%
def train_w2v(w2v_df):
    cores = multiprocessing.cpu_count()
    w2v_model = Word2Vec(min_count=2,
                         window=2,
                         vector_size=500, 
                         alpha=0.03, 
                         min_alpha=0.0007, 
                         sg=1,
                         workers=cores-1)
    
    w2v_model.build_vocab(w2v_df, progress_per=10000)
    w2v_model.train(w2v_df, total_examples=w2v_model.corpus_count, epochs=100, report_delay=1)
    return w2v_model

# %%
#getting size of the vector size for sentence
def getVectorSize():
    pass

# %%
df_fin_phrase[["sentence"]] = df_fin_phrase[["sentence"]].astype(str)
df_fin_phrase["sentence"] = df_fin_phrase["sentence"].apply(change_lower)
df_fin_phrase["sentence"] = df_fin_phrase["sentence"].apply(clean_data)
df_fin_phrase["sentence"] = df_fin_phrase["sentence"].apply(remover)

# %%
df_fin_phrase["sentence"]
# Out:
# 0       according gran company plans move production r...
# 1       technopolis plans develop stages area less squ...
# 2       international electronic industry company elco...
# 3       new production plant company would increase ca...
# 4       according company updated strategy years baswa...
#                               ...
# 4841    london marketwatch share prices ended lower lo...
# 4842    rinkuskiai beer sales fell per cent million li...
# 4843    operating profit fell eur mn eur mn including ...
# 4844    net sales paper segment decreased eur mn secon...
# 4845    sales finland decreased january sales outside ...
# Name: sentence, Length: 4846, dtype: object

# %%
w2v_df = get_w2vdf(df_fin_phrase)
w2v_model = train_w2v(w2v_df)

# %%
# print keys of the model
w2v_model.wv.key_to_index
# Out:
# {'': 0,
#  'eur': 1,
#  'company': 2,
#  'mn': 3,
#  'said': 4,
#  'finnish': 5,
#  'sales': 6,
#  'million': 7,
#  'net': 8,
#  'profit': 9,
#  'year': 10,
#  'finland': 11,
#  'group': 12,
#  'operating': 13,
#  'mln': 14,
#  'new': 15,
#  'business': 16,
#  'period': 17,
#  'quarter': 18,
#  'oyj': 19,
#  'share': 20,
#  'market': 21,
#  'also': 22,
#  'services': 23,
#  'shares': 24,
#  'first': 25,
#  'euro': 26,
#  'helsinki': 27,
#  'loss': 28,
#  'operations': 29,
#  'today': 30,
#  'compared': 31,
#  'contract': 32,
#  'nokia': 33,
#  'mobile': 34,
#  'total': 35,
#  'per': 36,
#  'financial': 37,
#  'based': 38,
#  'production': 39,
#  'products': 40,
#  'corporation': 41,
#  'percent': 42,
#  'bank': 43,
#  'according': 44,
#  'hel': 45,
#  'companies': 46,
#  'technology': 47,
#  'corresponding': 48,
#  'plant': 49,
#  'service': 50,
#  'v': 51,
#  'solutions': 52,
#  'construction': 53,
#  'one': 54,
#  'capital': 55,
#  'increased': 56,
#  'well': 57,
#  'agreement': 58,
#  'investment': 59,
#  'customers': 60,
#  'increase': 61,
#  'rose': 62,
#  'value': 63,
#  'pct': 64,
#  'order': 65,
#  'oy': 66,
#  'stock': 67,
#  'end': 68,
#  'second': 69,
#  'two': 70,
#  'january': 71,
#  'would': 72,
#  'unit': 73,
#  'omx': 74,
#  'board': 75,
#  'usd': 76,
#  'part': 77,
#  'development': 78,
#  'building': 79,
#  'industry': 80,
#  'management': 81,
#  'september': 82,
#  'earlier': 83,
#  'russia': 84,
#  'equipment': 85,
#  'paper': 86,
#  'result': 87,
#  'expected': 88,
#  'last': 89,
#  'project': 90,
#  'third': 91,
#  'decreased': 92,
#  'ceo': 93,
#  'us': 94,
#  'maker': 95,
#  'deal': 96,
#  'employees': 97,
#  'software': 98,
#  'signed': 99,
#  'price': 100,
#  'plc': 101,
#  'media': 102,
#  'systems': 103,
#  'announced': 104,
#  'real': 105,
#  'markets': 106,
#  'annual': 107,
#  'including': 108,
#  'global': 109,
#  'exchange': 110,
#  'approximately': 111,
#  'number': 112,
#  'data': 113,
#  'system': 114,
#  'people': 115,
#  'news': 116,
#  'area': 117,
#  'growth': 118,
#  'line': 119,
#  'acquisition': 120,
#  'billion': 121,
#  'ltd': 122,
#  'report': 123,
#  'may': 124,
#  'months': 125,
#  'october': 126,
#  'euros': 127,
#  'countries': 128,
#  'information': 129,
#  'june': 130,
#  'march': 131,
#  'use': 132,
#  'time': 133,
#  'manufacturing': 134,
#  'long': 135,
#  'however': 136,
#  'network': 137,
#  'stake': 138,
#  'world': 139,
#  'product': 140,
#  'half': 141,
#  'supply': 142,
#  'april': 143,
#  'includes': 144,
#  'largest': 145,
#  'engineering': 146,
#  'steel': 147,
#  'fell': 148,
#  'design': 149,
#  'high': 150,
#  'solution': 151,
#  'oil': 152,
#  'start': 153,
#  'swedish': 154,
#  'nordic': 155,
#  'reported': 156,
#  'made': 157,
#  'release': 158,
#  'energy': 159,
#  'subsidiary': 160,
#  'estimated': 161,
#  'three': 162,
#  'month': 163,
#  'china': 164,
#  'totalled': 165,
#  'years': 166,
#  'rights': 167,
#  'earnings': 168,
#  'nine': 169,
#  'office': 170,
#  'electronics': 171,
#  'include': 172,
#  'capacity': 173,
#  'expects': 174,
#  'transaction': 175,
#  'term': 176,
#  'manufacturer': 177,
#  'totaled': 178,
#  'e': 179,
#  'sale': 180,
#  'machinery': 181,
#  'industrial': 182,
#  'facility': 183,
#  'revenue': 184,
#  'cash': 185,
#  'power': 186,
#  'non': 187,
#  'president': 188,
#  'august': 189,
#  'negotiations': 190,
#  'sector': 191,
#  'eps': 192,
#  'says': 193,
#  'sweden': 194,
#  'international': 195,
#  'nordea': 196,
#  'units': 197,
#  'february': 198,
#  'basware': 199,
#  'related': 200,
#  'baltic': 201,
#  'europe': 202,
#  'ruukki': 203,
#  'process': 204,
#  'sell': 205,
#  'food': 206,
#  'phone': 207,
#  'stora': 208,
#  'director': 209,
#  'local': 210,
#  'developed': 211,
#  'provider': 212,
#  'projects': 213,
#  'completed': 214,
#  'corp': 215,
#  'around': 216,
#  'orders': 217,
#  'upm': 218,
#  'available': 219,
#  'cost': 220,
#  'networks': 221,
#  'addition': 222,
#  'november': 223,
#  'july': 224,
#  'russian': 225,
#  'inc': 226,
#  'lower': 227,
#  'leading': 228,
#  'elcoteq': 229,
#  'enso': 230,
#  'due': 231,
#  'plans': 232,
#  'option': 233,
#  'directors': 234,
#  'already': 235,
#  'significant': 236,
#  'retail': 237,
#  'shareholders': 238,
#  'division': 239,
#  'supplier': 240,
#  'distribution': 241,
#  'since': 242,
#  'brand': 243,
#  'day': 244,
#  'turnover': 245,
#  'strategy': 246,
#  'communications': 247,
#  'agreed': 248,
#  'center': 249,
#  'personnel': 250,
#  'capman': 251,
#  'added': 252,
#  'acquired': 253,
#  'general': 254,
#  'six': 255,
#  'continue': 256,
#  'st': 257,
#  'north': 258,
#  'yit': 259,
#  'customer': 260,
#  'offer': 261,
#  'amounted': 262,
#  'following': 263,
#  'currently': 264,
#  'range': 265,
#  'l': 266,
#  'prices': 267,
#  'n': 268,
#  'make': 269,
#  'provide': 270,
#  'next': 271,
#  'previously': 272,
#  'issue': 273,
#  'handling': 274,
#  'full': 275,
#  'fourth': 276,
#  'program': 277,
#  'security': 278,
#  'awarded': 279,
#  'fiskars': 280,
#  'cent': 281,
#  'performance': 282,
#  'estate': 283,
#  'petersburg': 284,
#  'position': 285,
#  'costs': 286,
#  'grew': 287,
#  'trade': 288,
#  'used': 289,
#  'target': 290,
#  'set': 291,
#  'major': 292,
#  'p': 293,
#  'alma': 294,
#  'maintenance': 295,
#  'bn': 296,
#  'credit': 297,
#  'friday': 298,
#  'four': 299,
#  'sampo': 300,
#  'results': 301,
#  'headquartered': 302,
#  'quality': 303,
#  'mr': 304,
#  'insurance': 305,
#  'processing': 306,
#  'meeting': 307,
#  'situation': 308,
#  'december': 309,
#  'city': 310,
#  'g': 311,
#  'mill': 312,
#  'ac': 313,
#  'co': 314,
#  'chain': 315,
#  'provides': 316,
#  'staff': 317,
#  'current': 318,
#  'internet': 319,
#  'press': 320,
#  'support': 321,
#  'chairman': 322,
#  'america': 323,
#  'focus': 324,
#  'com': 325,
#  'traffic': 326,
#  'owned': 327,
#  'items': 328,
#  'region': 329,
#  'cooperation': 330,
#  'work': 331,
#  'lay': 332,
#  'firm': 333,
#  'metso': 334,
#  'via': 335,
#  'dividend': 336,
#  'voting': 337,
#  'terms': 338,
#  'built': 339,
#  'delivered': 340,
#  'take': 341,
#  'volume': 342,
#  'started': 343,
#  'sports': 344,
#  'buy': 345,
#  'measures': 346,
#  'kemira': 347,
#  'forest': 348,
#  'cargotec': 349,
#  'plan': 350,
#  'u': 351,
#  'purchase': 352,
#  'several': 353,
#  'plants': 354,
#  'aspo': 355,
#  'pulp': 356,
#  'amount': 357,
#  'finnair': 358,
#  'applications': 359,
#  'pretax': 360,
#  'place': 361,
#  'worth': 362,
#  'reports': 363,
#  'ahlstrom': 364,
#  'devices': 365,
#  'research': 366,
#  'european': 367,
#  'demand': 368,
#  'areas': 369,
#  'state': 370,
#  'delivery': 371,
#  'higher': 372,
#  'fixed': 373,
#  'previous': 374,
#  'future': 375,
#  'rental': 376,
#  'savings': 377,
#  'strong': 378,
#  'ab': 379,
#  'b': 380,
#  'level': 381,
#  'marketing': 382,
#  'sanoma': 383,
#  'central': 384,
#  'stockmann': 385,
#  'investments': 386,
#  'teliasonera': 387,
#  'sold': 388,
#  'www': 389,
#  'issued': 390,
#  'deliver': 391,
#  'recurring': 392,
#  'estonia': 393,
#  'posted': 394,
#  'margin': 395,
#  'whole': 396,
#  'store': 397,
#  'positive': 398,
#  'adp': 399,
#  'teleste': 400,
#  'joint': 401,
#  'developer': 402,
#  'poyry': 403,
#  'chief': 404,
#  'members': 405,
#  'held': 406,
#  'uk': 407,
#  'packaging': 408,
#  'materials': 409,
#  'transfer': 410,
#  'application': 411,
#  'offering': 412,
#  'device': 413,
#  'base': 414,
#  'ago': 415,
#  'decision': 416,
#  'expand': 417,
#  'received': 418,
#  'life': 419,
#  'decided': 420,
#  'flow': 421,
#  'afx': 422,
#  'secure': 423,
#  'online': 424,
#  'corporate': 425,
#  'main': 426,
#  'contracts': 427,
#  'neste': 428,
#  'commercial': 429,
#  'aspocomp': 430,
#  'infrastructure': 431,
#  'excluding': 432,
#  'income': 433,
#  'q': 434,
#  'large': 435,
#  'outotec': 436,
#  'water': 437,
#  'operators': 438,
#  'scanfil': 439,
#  'pohjola': 440,
#  'tonnes': 441,
#  'wednesday': 442,
#  'cut': 443,
#  'holding': 444,
#  'launch': 445,
#  'telecom': 446,
#  'employs': 447,
#  'logistics': 448,
#  'using': 449,
#  'strategic': 450,
#  'manager': 451,
#  'sek': 452,
#  'making': 453,
#  'technologies': 454,
#  'x': 455,
#  'key': 456,
#  'taxes': 457,
#  'analysis': 458,
#  'cramo': 459,
#  'square': 460,
#  'published': 461,
#  'combined': 462,
#  'index': 463,
#  'executive': 464,
#  'aim': 465,
#  'pharmaceutical': 466,
#  'content': 467,
#  'incap': 468,
#  'close': 469,
#  'five': 470,
#  'government': 471,
#  'rapala': 472,
#  'yesterday': 473,
#  'head': 474,
#  'disclosed': 475,
#  'elisa': 476,
#  'partner': 477,
#  'okmetic': 478,
#  'interest': 479,
#  'best': 480,
#  'germany': 481,
#  'scheduled': 482,
#  'existing': 483,
#  'established': 484,
#  'beer': 485,
#  'glass': 486,
#  'kesko': 487,
#  'remain': 488,
#  'acquire': 489,
#  'managing': 490,
#  'india': 491,
#  'different': 492,
#  'paid': 493,
#  'shipping': 494,
#  'tikkurila': 495,
#  'glaston': 496,
#  'details': 497,
#  'respectively': 498,
#  'consumers': 499,
#  'activities': 500,
#  'good': 501,
#  'public': 502,
#  'provided': 503,
#  'operates': 504,
#  'site': 505,
#  'covers': 506,
#  'deliveries': 507,
#  'funds': 508,
#  'property': 509,
#  'maximum': 510,
#  'owner': 511,
#  'investors': 512,
#  'digital': 513,
#  'portfolio': 514,
#  'experience': 515,
#  'componenta': 516,
#  'brands': 517,
#  'aldata': 518,
#  'sq': 519,
#  'facilities': 520,
#  'phones': 521,
#  'atria': 522,
#  'operation': 523,
#  'offers': 524,
#  'improve': 525,
#  'handset': 526,
#  'rautaruukki': 527,
#  'marimekko': 528,
#  'poland': 529,
#  'electronic': 530,
#  'move': 531,
#  'operator': 532,
#  'developing': 533,
#  'asia': 534,
#  'resources': 535,
#  'outokumpu': 536,
#  'enable': 537,
#  'fortum': 538,
#  'listed': 539,
#  'closed': 540,
#  'mid': 541,
#  'tuesday': 542,
#  'invest': 543,
#  'planning': 544,
#  'fund': 545,
#  'subscription': 546,
#  'consumer': 547,
#  'located': 548,
#  'generated': 549,
#  'stores': 550,
#  'konecranes': 551,
#  'cover': 552,
#  'kymmene': 553,
#  'natural': 554,
#  'material': 555,
#  'raw': 556,
#  'went': 557,
#  'estimates': 558,
#  'kone': 559,
#  'gas': 560,
#  'businesses': 561,
#  'park': 562,
#  'continued': 563,
#  'improved': 564,
#  'nasdaq': 565,
#  'within': 566,
#  'platform': 567,
#  'providing': 568,
#  'home': 569,
#  'structures': 570,
#  'video': 571,
#  'become': 572,
#  'london': 573,
#  'options': 574,
#  'control': 575,
#  'versus': 576,
#  'included': 577,
#  'thursday': 578,
#  'makes': 579,
#  'venture': 580,
#  'south': 581,
#  'temporary': 582,
#  'another': 583,
#  'low': 584,
#  'restructuring': 585,
#  'administration': 586,
#  'investor': 587,
#  'lead': 588,
#  'enables': 589,
#  'metal': 590,
#  'broadband': 591,
#  'tekla': 592,
#  'present': 593,
#  'properties': 594,
#  'small': 595,
#  'segment': 596,
#  'espoo': 597,
#  'cargo': 598,
#  'offs': 599,
#  'bridge': 600,
#  'build': 601,
#  'meat': 602,
#  'planned': 603,
#  'liters': 604,
#  'bought': 605,
#  'entire': 606,
#  'printing': 607,
#  'summer': 608,
#  'beginning': 609,
#  'france': 610,
#  'stockholm': 611,
#  'way': 612,
#  'raisio': 613,
#  'recently': 614,
#  'private': 615,
#  'fiscal': 616,
#  'magazine': 617,
#  'efficiency': 618,
#  'fully': 619,
#  'assets': 620,
#  'effect': 621,
#  'r': 622,
#  'house': 623,
#  'monday': 624,
#  'points': 625,
#  'automation': 626,
#  'date': 627,
#  'machines': 628,
#  'responsible': 629,
#  'subscribed': 630,
#  'clients': 631,
#  'talvivaara': 632,
#  'expansion': 633,
#  'siemens': 634,
#  'carried': 635,
#  'growing': 636,
#  'telecommunications': 637,
#  'announcement': 638,
#  'ramirent': 639,
#  'outlook': 640,
#  'working': 641,
#  'trading': 642,
#  'vice': 643,
#  'access': 644,
#  'structure': 645,
#  'vaahto': 646,
#  'land': 647,
#  'change': 648,
#  'users': 649,
#  'tools': 650,
#  'fair': 651,
#  'team': 652,
#  'pay': 653,
#  'persons': 654,
#  'consolidated': 655,
#  'agreements': 656,
#  'installation': 657,
#  'va': 658,
#  'cencorp': 659,
#  'alexandria': 660,
#  'concerning': 661,
#  'machine': 662,
#  'space': 663,
#  'operational': 664,
#  'patent': 665,
#  'complete': 666,
#  'panostaja': 667,
#  'digia': 668,
#  'known': 669,
#  'treatment': 670,
#  'aims': 671,
#  'suomen': 672,
#  'industries': 673,
#  'near': 674,
#  'reporting': 675,
#  'country': 676,
#  'pre': 677,
#  'holdings': 678,
#  'communication': 679,
#  'jobs': 680,
#  'raute': 681,
#  'changes': 682,
#  'vaisala': 683,
#  'slightly': 684,
#  'negative': 685,
#  'week': 686,
#  'wood': 687,
#  'latest': 688,
#  'shopping': 689,
#  'f': 690,
#  'mainly': 691,
#  'return': 692,
#  'norway': 693,
#  'factory': 694,
#  'port': 695,
#  'told': 696,
#  'technopolis': 697,
#  'lines': 698,
#  'partners': 699,
#  'comptel': 700,
#  'wireless': 701,
#  'name': 702,
#  'national': 703,
#  'given': 704,
#  'method': 705,
#  'revenues': 706,
#  'olvi': 707,
#  'representing': 708,
#  'tax': 709,
#  'narrowed': 710,
#  'owns': 711,
#  'banks': 712,
#  'states': 713,
#  'northern': 714,
#  'web': 715,
#  'rise': 716,
#  'able': 717,
#  'right': 718,
#  'location': 719,
#  'starting': 720,
#  'clothing': 721,
#  'back': 722,
#  'equity': 723,
#  'biohit': 724,
#  'lemminkainen': 725,
#  'biggest': 726,
#  'remaining': 727,
#  'outside': 728,
#  'daily': 729,
#  'important': 730,
#  'manufacture': 731,
#  'loan': 732,
#  'moscow': 733,
#  'core': 734,
#  'efficient': 735,
#  'talentum': 736,
#  'additional': 737,
#  'financing': 738,
#  'music': 739,
#  'spring': 740,
#  'sponda': 741,
#  'selling': 742,
#  'japan': 743,
#  'strengthen': 744,
#  'passenger': 745,
#  'department': 746,
#  'record': 747,
#  'electricity': 748,
#  'uponor': 749,
#  'analyst': 750,
#  'pension': 751,
#  'shareholder': 752,
#  'short': 753,
#  'declined': 754,
#  'competition': 755,
#  'various': 756,
#  'rate': 757,
#  'develop': 758,
#  'register': 759,
#  'domestic': 760,
#  'banking': 761,
#  'eastern': 762,
#  'goods': 763,
#  'technical': 764,
#  'nyse': 765,
#  'economic': 766,
#  'reductions': 767,
#  'czech': 768,
#  'cutting': 769,
#  'united': 770,
#  'statement': 771,
#  'approval': 772,
#  'offices': 773,
#  'indian': 774,
#  'oct': 775,
#  'came': 776,
#  'top': 777,
#  'norwegian': 778,
#  'dec': 779,
#  'generation': 780,
#  'transportation': 781,
#  'producer': 782,
#  'bring': 783,
#  'form': 784,
#  'feb': 785,
#  'charging': 786,
#  'impact': 787,
#  'usa': 788,
#  'almost': 789,
#  'viking': 790,
#  'without': 791,
#  'member': 792,
#  'approved': 793,
#  'later': 794,
#  'continuing': 795,
#  'dropped': 796,
#  'volumes': 797,
#  'worldwide': 798,
#  'enterprise': 799,
#  'parties': 800,
#  'social': 801,
#  'efore': 802,
#  'wide': 803,
#  'salcomp': 804,
#  'lithuania': 805,
#  'diluted': 806,
#  'manufactures': 807,
#  'tampere': 808,
#  'acquisitions': 809,
#  'conditions': 810,
#  'stood': 811,
#  'bond': 812,
#  'metals': 813,
#  'invoice': 814,
#  'pleased': 815,
#  'completion': 816,
#  'east': 817,
#  'temporarily': 818,
#  'union': 819,
#  'launched': 820,
#  'huhtamaki': 821,
#  'presence': 822,
#  'amer': 823,
#  'open': 824,
#  'tons': 825,
#  'among': 826,
#  'many': 827,
#  'early': 828,
#  'suominen': 829,
#  'improvement': 830,
#  'potential': 831,
#  'k': 832,
#  'works': 833,
#  'designed': 834,
#  'raised': 835,
#  'waste': 836,
#  'produced': 837,
#  'model': 838,
#  'forward': 839,
#  'sum': 840,
#  'metres': 841,
#  'jan': 842,
#  'tallinn': 843,
#  'components': 844,
#  'voice': 845,
#  'tiimari': 846,
#  'environment': 847,
#  'workers': 848,
#  'analysts': 849,
#  'stainless': 850,
#  'serve': 851,
#  'fall': 852,
#  'benefon': 853,
#  'consumption': 854,
#  'holds': 855,
#  'brazil': 856,
#  'autumn': 857,
#  'american': 858,
#  'registered': 859,
#  'reduction': 860,
#  'senior': 861,
#  'ten': 862,
#  'cranes': 863,
#  'affecto': 864,
#  'weeks': 865,
#  'gain': 866,
#  'directed': 867,
#  'reach': 868,
#  'like': 869,
#  'expertise': 870,
#  'especially': 871,
#  'establish': 872,
#  'republic': 873,
#  'airline': 874,
#  'much': 875,
#  'ship': 876,
#  'mills': 877,
#  'bid': 878,
#  'special': 879,
#  'latvia': 880,
#  'together': 881,
#  'phase': 882,
#  'africa': 883,
#  'southern': 884,
#  'selected': 885,
#  'clear': 886,
#  'actual': 887,
#  'nok': 888,
#  'user': 889,
#  'c': 890,
#  'calls': 891,
#  'basis': 892,
#  'overall': 893,
#  'employment': 894,
#  'oulu': 895,
#  'employee': 896,
#  'fuel': 897,
#  'vacon': 898,
#  'comparable': 899,
#  'gave': 900,
#  'see': 901,
#  'environmental': 902,
#  'processes': 903,
#  'sectors': 904,
#  'controlled': 905,
#  'seen': 906,
#  'tel': 907,
#  'forecasts': 908,
#  'rates': 909,
#  'side': 910,
#  'entered': 911,
#  'eu': 912,
#  'ebit': 913,
#  'levels': 914,
#  'mail': 915,
#  'safety': 916,
#  'papers': 917,
#  'still': 918,
#  'heating': 919,
#  'gives': 920,
#  'asset': 921,
#  'far': 922,
#  'vantaa': 923,
#  'give': 924,
#  'consulting': 925,
#  'ore': 926,
#  'act': 927,
#  'ensure': 928,
#  'statements': 929,
#  'accordance': 930,
#  'come': 931,
#  'released': 932,
#  'personal': 933,
#  'newspaper': 934,
#  'across': 935,
#  'officer': 936,
#  'managed': 937,
#  'thomson': 938,
#  'needs': 939,
#  'activity': 940,
#  'citycon': 941,
#  'hk': 942,
#  'disclose': 943,
#  'competitive': 944,
#  'pharmaceuticals': 945,
#  'hkscan': 946,
#  'study': 947,
#  'hand': 948,
#  'tecnomen': 949,
#  'ixonos': 950,
#  'manufacturers': 951,
#  'chemicals': 952,
#  'jyvaskyla': 953,
#  'exports': 954,
#  'mining': 955,
#  'ordered': 956,
#  'sto': 957,
#  'residential': 958,
#  'conference': 959,
#  'free': 960,
#  'orion': 961,
#  'silicon': 962,
#  'acquiring': 963,
#  'fishing': 964,
#  'less': 965,
#  'targets': 966,
#  'ownership': 967,
#  'terminal': 968,
#  'concern': 969,
#  'nokian': 970,
#  'tyres': 971,
#  'double': 972,
#  'partnership': 973,
#  'liquid': 974,
#  'reached': 975,
#  'route': 976,
#  'taken': 977,
#  'mw': 978,
#  'cap': 979,
#  'amounts': 980,
#  'similar': 981,
#  'italy': 982,
#  'class': 983,
#  'hit': 984,
#  'estonian': 985,
#  'denmark': 986,
#  'specialty': 987,
#  'flexible': 988,
#  'adpnews': 989,
#  'recorded': 990,
#  'player': 991,
#  'hold': 992,
#  'better': 993,
#  'street': 994,
#  'job': 995,
#  'carrier': 996,
#  'eb': 997,
#  'reduce': 998,
#  'publish': 999,
#  ...}

# %%
# window of 6
w2v_model.wv.most_similar("publish")
# Out:
# [('bulletin', 0.5709467530250549),
#  ('eet', 0.5367853045463562),
#  ('analyses', 0.5361486673355103),
#  ('summary', 0.4960907995700836),
#  ('books', 0.4860750138759613),
#  ('statements', 0.481698602437973),
#  ('interim', 0.47395867109298706),
#  ('viii', 0.4587167203426361),
#  ('pakistan', 0.45790576934814453),
#  ('announcement', 0.45124995708465576)]

# %%
# window of 2
w2v_model.wv.most_similar("publish")
# Out:
# [('revealed', 0.5955195426940918),
#  ('anne', 0.5440590977668762),
#  ('interim', 0.5399895906448364),
#  ('biomass', 0.5242285132408142),
#  ('bulletin', 0.5096632242202759),
#  ('hydrogen', 0.5056923627853394),
#  ('peroxide', 0.5012044310569763),
#  ('analyses', 0.49967774748802185),
#  ('books', 0.4982476830482483),
#  ('unaudited', 0.4959008991718292)]

# %%
w2v_model.wv.most_similar("publish")
